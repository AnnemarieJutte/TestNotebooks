# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# My first cell

# %%
my_string = "hello world 1.0"
my_string
# Out:
# 'hello world 4.0'

# %%
x = 1 + 3

# %% [markdown]
# Even more cells

# %%
x
# Out:
# 2

# %%
x= np.array([0, 1, 2])
y = np.array([10, 15, 12])

# %%
plt.plot(x, y)
